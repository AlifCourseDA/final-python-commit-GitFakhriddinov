# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 1: Working with Git
#
# In this exercise I ask you to edit the notebook by answering the questions below,
# create new files, and commit all the changes in the repository before pushing
# your changes to the GitHub server.
#
# **About you**
#
# Answer the questions below to let me to know you better.
#
# *None of the questions is compulsory*, please only share the information you would be comfortable to share in an ice-breaking exercise in the class.
#
# For each answer create a new Jupyter cell under each question.
# Don’t forget to change it type to ‘Markdown’ to write text.
# Here is a short [list of Markdown commands for editing text](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet).

# %% [markdown]
# ## Question 1: What is your name?  What is your preferred name or nick name I should use?

# %% [markdown]
# Hi, I am Baxtiyor and I don't use nicknames, so you can call me by my name

# %% [markdown]
# ## Question 2: Where are you from?

# %% [markdown]
# I come from Fergana

# %% [markdown]
# ## Question 3: What is your background? Where do you work/study?

# %% [markdown]
# Well, I am a student in TUIT locals call it TATU, my major is e-commerce.

# %% [markdown]
# ## Question 4: Have you evered learned to code before?

# %% [markdown]
# I did to some extend, my first language was HTML, which I forgot most of it ((, then I learned basiccommands in python from the book called "Python Crash Course" by Eric Matthews

# %% [markdown]
# ## Question 5: What is your main motivation to take the Data Analytics course?

# %% [markdown]
# My main goal is to get the islamic Banking as dominant as the standard banks. to split my goal to steps I use the question "How?". How can I make the islamic banking dominant? by starting one or contributing to success of an existing one. How can I have my most impact in the bank? by helping the company to find the fastest way of the success. How to help on that? by being a Data Analyst. How do I become Data Analyst that is good at finance? Alif Data analytics is the answer)

# %% [markdown]
# ## Question 6: What is your active email address?

# %% [markdown]
# fbakhtiyorjon@gmail.com

# %% [markdown]
# ## Picture
#
# Copy a small picture (avatar/scenery/pet), into the same directory as this Jupyter notebook,
# and insert it into a new cell using the following command:
#
# `![](NAME_OF_FILE.jpg)`
#
# Then ‘Run’ the cell by pressing `Shift-Enter` to see the picture appear.

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# ## Submit your info
#
# 1. Save the notebook by clicking the *floppy disk* icon in the toolbar, or pressing `Ctr-S`
# 1. Switch to your Git program
# 1. Observe the difference in the notebook, and the new picture file in diffs
# 1. Commit all the changes
# 1. Push your work to the server
